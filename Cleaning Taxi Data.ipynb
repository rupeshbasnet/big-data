# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv 
import dateutil

# %%
import pandas as pd
# only read the top 10000
df = pd.read_csv('Data/yellow_tripdata_2016-06.csv')

# %%
# Show the top 10 rows
df[:10]
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-06-09 21:06:36   2016-06-09 21:13:08                2
# 1         2  2016-06-09 21:06:36   2016-06-09 21:35:11                1
# 2         2  2016-06-09 21:06:36   2016-06-09 21:13:10                1
# 3         2  2016-06-09 21:06:36   2016-06-09 21:36:10                1
# 4         2  2016-06-09 21:06:36   2016-06-09 21:23:23                1
# 5         2  2016-06-09 21:06:36   2016-06-09 21:19:21                1
# 6         2  2016-06-09 21:06:36   2016-06-09 21:30:13                5
# 7         1  2016-06-09 21:06:37   2016-06-09 21:16:47                1
# 8         1  2016-06-09 21:06:37   2016-06-09 21:15:44                1
# 9         1  2016-06-09 21:06:37   2016-06-09 21:23:57                2
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.79        -73.983360        40.760937           1
# 1           5.22        -73.981720        40.736668           1
# 2           1.26        -73.994316        40.751072           1
# 3           7.39        -73.982361        40.773891           1
# 4           3.10        -73.987106        40.733173           1
# 5           2.17        -73.995201        40.739491           1
# 6           6.02        -73.980476        40.741680           1
# 7           1.40        -73.985703        40.746742           1
# 8           1.20        -73.984276        40.775009           1
# 9           1.90        -73.977921        40.750092           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.977463         40.753979             2
# 1                  N         -73.981636         40.670242             1
# 2                  N         -74.004234         40.742168             1
# 3                  N         -73.929466         40.851540             1
# 4                  N         -73.985909         40.766445             1
# 5                  N         -73.993202         40.762642             1
# 6                  N         -73.902962         40.748741             2
# 7                  N         -73.982506         40.762772             1
# 8                  N         -73.968498         40.766430             2
# 9                  N         -73.987236         40.749359             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          6.0    0.5      0.5        0.00           0.0
# 1         22.0    0.5      0.5        4.00           0.0
# 2          6.5    0.5      0.5        1.56           0.0
# 3         26.0    0.5      0.5        1.00           0.0
# 4         13.5    0.5      0.5        2.96           0.0
# 5         10.5    0.5      0.5        2.36           0.0
# 6         21.5    0.5      0.5        0.00           0.0
# 7          8.5    0.5      0.5        1.95           0.0
# 8          8.0    0.5      0.5        0.00           0.0
# 9         12.0    0.5      0.5        3.33           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          7.30
# 1                    0.3         27.30
# 2                    0.3          9.36
# 3                    0.3         28.30
# 4                    0.3         17.76
# 5                    0.3         14.16
# 6                    0.3         22.80
# 7                    0.3         11.75
# 8                    0.3          9.30
# 9                    0.3         16.63

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-06-09 21:06:36   2016-06-09 21:13:08                2
# 1         2  2016-06-09 21:06:36   2016-06-09 21:35:11                1
# 2         2  2016-06-09 21:06:36   2016-06-09 21:13:10                1
# 3         2  2016-06-09 21:06:36   2016-06-09 21:36:10                1
# 4         2  2016-06-09 21:06:36   2016-06-09 21:23:23                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.79        -73.983360        40.760937           1
# 1           5.22        -73.981720        40.736668           1
# 2           1.26        -73.994316        40.751072           1
# 3           7.39        -73.982361        40.773891           1
# 4           3.10        -73.987106        40.733173           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.977463         40.753979             2
# 1                  N         -73.981636         40.670242             1
# 2                  N         -74.004234         40.742168             1
# 3                  N         -73.929466         40.851540             1
# 4                  N         -73.985909         40.766445             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          6.0    0.5      0.5        0.00           0.0
# 1         22.0    0.5      0.5        4.00           0.0
# 2          6.5    0.5      0.5        1.56           0.0
# 3         26.0    0.5      0.5        1.00           0.0
# 4         13.5    0.5      0.5        2.96           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          7.30
# 1                    0.3         27.30
# 2                    0.3          9.36
# 3                    0.3         28.30
# 4                    0.3         17.76

# %%
df.shape
# Out:
# (11135470, 19)

# %%
df.columns
# Out:
# Index([u'VendorID', u'tpep_pickup_datetime', u'tpep_dropoff_datetime',
#        u'passenger_count', u'trip_distance', u'pickup_longitude',
#        u'pickup_latitude', u'RatecodeID', u'store_and_fwd_flag',
#        u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
#        u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
#        u'improvement_surcharge', u'total_amount'],
#       dtype='object')

# %%
df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
df["tpep_pickup_datetime"] = pd.to_datetime(df.tpep_pickup_datetime, format="%Y/%m/%d %H:%M:%S")
df["tpep_dropoff_datetime"] = pd.to_datetime(df.tpep_dropoff_datetime, format="%Y/%m/%d %H:%M:%S")

# %%
# Adding the weekday
df['Index_Weekday'] = pd.to_datetime(df['tpep_pickup_datetime'])
days = {0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'}
df['Index_Weekday'] = df['Index_Weekday'].dt.dayofweek
df['Weekday'] = df['Index_Weekday'].apply(lambda x: days[x])

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-06-09 21:06:36   2016-06-09 21:13:08                2
# 1         2  2016-06-09 21:06:36   2016-06-09 21:35:11                1
# 2         2  2016-06-09 21:06:36   2016-06-09 21:13:10                1
# 3         2  2016-06-09 21:06:36   2016-06-09 21:36:10                1
# 4         2  2016-06-09 21:06:36   2016-06-09 21:23:23                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.79        -73.983360        40.760937           1
# 1           5.22        -73.981720        40.736668           1
# 2           1.26        -73.994316        40.751072           1
# 3           7.39        -73.982361        40.773891           1
# 4           3.10        -73.987106        40.733173           1
#
#   store_and_fwd_flag  dropoff_longitude    ...     payment_type  fare_amount  \
# 0                  N         -73.977463    ...                2          6.0
# 1                  N         -73.981636    ...                1         22.0
# 2                  N         -74.004234    ...                1          6.5
# 3                  N         -73.929466    ...                1         26.0
# 4                  N         -73.985909    ...                1         13.5
#
#    extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 0    0.5      0.5        0.00           0.0                    0.3
# 1    0.5      0.5        4.00           0.0                    0.3
# 2    0.5      0.5        1.56           0.0                    0.3
# 3    0.5      0.5        1.00           0.0                    0.3
# 4    0.5      0.5        2.96           0.0                    0.3
#
#    total_amount  Index_Weekday   Weekday
# 0          7.30              3  Thursday
# 1         27.30              3  Thursday
# 2          9.36              3  Thursday
# 3         28.30              3  Thursday
# 4         17.76              3  Thursday
#
# [5 rows x 21 columns]

# %%
df = df.drop(['VendorID'], axis=1)
df = df.drop(['trip_distance'], axis=1)
df = df.drop(['RatecodeID'], axis=1)
df = df.drop(['store_and_fwd_flag'], axis=1)

# %%
df = df.drop(['payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount'], axis=1)

# %%
df = df.drop(['passenger_count'], axis=1)

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08        -73.983360
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11        -73.981720
# 2  2016-06-09 21:06:36   2016-06-09 21:13:10        -73.994316
# 3  2016-06-09 21:06:36   2016-06-09 21:36:10        -73.982361
# 4  2016-06-09 21:06:36   2016-06-09 21:23:23        -73.987106
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  Index_Weekday  \
# 0        40.760937         -73.977463         40.753979              3
# 1        40.736668         -73.981636         40.670242              3
# 2        40.751072         -74.004234         40.742168              3
# 3        40.773891         -73.929466         40.851540              3
# 4        40.733173         -73.985909         40.766445              3
#
#     Weekday
# 0  Thursday
# 1  Thursday
# 2  Thursday
# 3  Thursday
# 4  Thursday

# %%
# Removing pickup long and lat with 0 removed
df = df[df.pickup_longitude != 0]

# %%
#df[:100]

# %%
plt.figure(figsize=(18,9))
for row in df[:1000].itertuples():
    lon_x=row.pickup_longitude
    lat_y=row.pickup_latitude
    plt.scatter(lon_x,lat_y,alpha=0.2,s=100)
    
plt.axis([-74.04,-73.90,40.675,40.825])
plt.title("visualization for top 100")
plt.show()

# %%
df.shape
# Out:
# (10996648, 8)

# %%
import datetime as dt
df['Date'] = df['tpep_pickup_datetime'].apply(lambda x: x.strftime('%m/%d/%Y'))

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08        -73.983360
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11        -73.981720
# 2  2016-06-09 21:06:36   2016-06-09 21:13:10        -73.994316
# 3  2016-06-09 21:06:36   2016-06-09 21:36:10        -73.982361
# 4  2016-06-09 21:06:36   2016-06-09 21:23:23        -73.987106
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  Index_Weekday  \
# 0        40.760937         -73.977463         40.753979              3
# 1        40.736668         -73.981636         40.670242              3
# 2        40.751072         -74.004234         40.742168              3
# 3        40.773891         -73.929466         40.851540              3
# 4        40.733173         -73.985909         40.766445              3
#
#     Weekday        Date
# 0  Thursday  06/09/2016
# 1  Thursday  06/09/2016
# 2  Thursday  06/09/2016
# 3  Thursday  06/09/2016
# 4  Thursday  06/09/2016

# %%
# load the weather Data
dfWeather= pd.read_csv('Data/Weather NYC 2016.csv')

# %%
dfWeather.head()
dfWeather = dfWeather.fillna('Normal')
dfWeather.head()
# Out:
#          Date  DateVal  Temp Conditions
# 0  01/01/2016        1    38     Normal
# 1  01/02/2016        2    36     Normal
# 2  01/03/2016        3    40     Normal
# 3  01/04/2016        4    25     Normal
# 4  01/05/2016        5    20     Normal

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08        -73.983360
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11        -73.981720
# 2  2016-06-09 21:06:36   2016-06-09 21:13:10        -73.994316
# 3  2016-06-09 21:06:36   2016-06-09 21:36:10        -73.982361
# 4  2016-06-09 21:06:36   2016-06-09 21:23:23        -73.987106
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  Index_Weekday  \
# 0        40.760937         -73.977463         40.753979              3
# 1        40.736668         -73.981636         40.670242              3
# 2        40.751072         -74.004234         40.742168              3
# 3        40.773891         -73.929466         40.851540              3
# 4        40.733173         -73.985909         40.766445              3
#
#     Weekday        Date
# 0  Thursday  06/09/2016
# 1  Thursday  06/09/2016
# 2  Thursday  06/09/2016
# 3  Thursday  06/09/2016
# 4  Thursday  06/09/2016

# %%
df = df.merge(dfWeather, on='Date', how='left')
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08        -73.983360
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11        -73.981720
# 2  2016-06-09 21:06:36   2016-06-09 21:13:10        -73.994316
# 3  2016-06-09 21:06:36   2016-06-09 21:36:10        -73.982361
# 4  2016-06-09 21:06:36   2016-06-09 21:23:23        -73.987106
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  Index_Weekday  \
# 0        40.760937         -73.977463         40.753979              3
# 1        40.736668         -73.981636         40.670242              3
# 2        40.751072         -74.004234         40.742168              3
# 3        40.773891         -73.929466         40.851540              3
# 4        40.733173         -73.985909         40.766445              3
#
#     Weekday        Date  DateVal  Temp Conditions
# 0  Thursday  06/09/2016        9    63     Normal
# 1  Thursday  06/09/2016        9    63     Normal
# 2  Thursday  06/09/2016        9    63     Normal
# 3  Thursday  06/09/2016        9    63     Normal
# 4  Thursday  06/09/2016        9    63     Normal

# %%
df.groupby(['Date'])

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08        -73.983360
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11        -73.981720
# 2  2016-06-09 21:06:36   2016-06-09 21:13:10        -73.994316
# 3  2016-06-09 21:06:36   2016-06-09 21:36:10        -73.982361
# 4  2016-06-09 21:06:36   2016-06-09 21:23:23        -73.987106
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  Index_Weekday  \
# 0        40.760937         -73.977463         40.753979              3
# 1        40.736668         -73.981636         40.670242              3
# 2        40.751072         -74.004234         40.742168              3
# 3        40.773891         -73.929466         40.851540              3
# 4        40.733173         -73.985909         40.766445              3
#
#     Weekday        Date  DateVal  Temp Conditions
# 0  Thursday  06/09/2016        9    63     Normal
# 1  Thursday  06/09/2016        9    63     Normal
# 2  Thursday  06/09/2016        9    63     Normal
# 3  Thursday  06/09/2016        9    63     Normal
# 4  Thursday  06/09/2016        9    63     Normal

# %%
df.to_csv('Data/merged_Data_Taxi.csv')

# %%
groupByKeysDate = df['Date']

# %%
df.groupby(groupByKeysDate)

# %%
df.tail()
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 10996643  2016-06-21 22:08:42   2016-06-21 22:14:09        -73.971756
# 10996644  2016-06-21 22:08:42   2016-06-21 22:15:02        -73.989693
# 10996645  2016-06-21 22:08:42   2016-06-21 22:22:33        -73.973473
# 10996646  2016-06-21 22:08:42   2016-06-21 22:28:08        -73.936806
# 10996647  2016-06-21 22:08:42   2016-06-21 22:23:00        -73.991432
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  Index_Weekday  \
# 10996643        40.765923         -73.986893         40.761093              1
# 10996644        40.735512         -73.979645         40.747814              1
# 10996645        40.763695         -74.001244         40.743172              1
# 10996646        40.798347         -73.997818         40.726055              1
# 10996647        40.735260         -73.984642         40.768871              1
#
#           Weekday        Date  DateVal  Temp Conditions
# 10996643  Tuesday  06/21/2016       21    80       Rain
# 10996644  Tuesday  06/21/2016       21    80       Rain
# 10996645  Tuesday  06/21/2016       21    80       Rain
# 10996646  Tuesday  06/21/2016       21    80       Rain
# 10996647  Tuesday  06/21/2016       21    80       Rain

# %%
#count values of the Date
df.Date.value_counts().sort_index()
# Out:
# 06/01/2016    364184
# 06/02/2016    388191
# 06/03/2016    396886
# 06/04/2016    415745
# 06/05/2016    348885
# 06/06/2016    352084
# 06/07/2016    371836
# 06/08/2016    376812
# 06/09/2016    388379
# 06/10/2016    396105
# 06/11/2016    383139
# 06/12/2016    325122
# 06/13/2016    336441
# 06/14/2016    358742
# 06/15/2016    378382
# 06/16/2016    394110
# 06/17/2016    383328
# 06/18/2016    365906
# 06/19/2016    326273
# 06/20/2016    331976
# 06/21/2016    360246
# 06/22/2016    369098
# 06/23/2016    384969
# 06/24/2016    383364
# 06/25/2016    383815
# 06/26/2016    327751
# 06/27/2016    354228
# 06/28/2016    344322
# 06/29/2016    352607
# 06/30/2016    353722
# Name: Date, dtype: int64

# %%
dfAggValues = pd.DataFrame(df.Date.value_counts().sort_index().reset_index())

# %%
dfAggValues = dfAggValues.rename(columns={'index':'Date','Date':'Count'})

# %%
dfAggValues.columns
# Out:
# Index([u'Date', u'Count'], dtype='object')

# %%
dfAggValues['Index_Weekday'] = pd.to_datetime(dfAggValues['Date'])
days = {0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'}
dfAggValues['Index_Weekday'] = dfAggValues['Index_Weekday'].dt.dayofweek
dfAggValues['Weekday'] = dfAggValues['Index_Weekday'].apply(lambda x: days[x])

# %%
dfAggValues
# Out:
#           Date   Count  Index_Weekday    Weekday
# 0   06/01/2016  364184              2  Wednesday
# 1   06/02/2016  388191              3   Thursday
# 2   06/03/2016  396886              4     Friday
# 3   06/04/2016  415745              5   Saturday
# 4   06/05/2016  348885              6     Sunday
# 5   06/06/2016  352084              0     Monday
# 6   06/07/2016  371836              1    Tuesday
# 7   06/08/2016  376812              2  Wednesday
# 8   06/09/2016  388379              3   Thursday
# 9   06/10/2016  396105              4     Friday
# 10  06/11/2016  383139              5   Saturday
# 11  06/12/2016  325122              6     Sunday
# 12  06/13/2016  336441              0     Monday
# 13  06/14/2016  358742              1    Tuesday
# 14  06/15/2016  378382              2  Wednesday
# 15  06/16/2016  394110              3   Thursday
# 16  06/17/2016  383328              4     Friday
# 17  06/18/2016  365906              5   Saturday
# 18  06/19/2016  326273              6     Sunday
# 19  06/20/2016  331976              0     Monday
# 20  06/21/2016  360246              1    Tuesday
# 21  06/22/2016  369098              2  Wednesday
# 22  06/23/2016  384969              3   Thursday
# 23  06/24/2016  383364              4     Friday
# 24  06/25/2016  383815              5   Saturday
# 25  06/26/2016  327751              6     Sunday
# 26  06/27/2016  354228              0     Monday
# 27  06/28/2016  344322              1    Tuesday
# 28  06/29/2016  352607              2  Wednesday
# 29  06/30/2016  353722              3   Thursday

# %%
plt.style.use('seaborn-whitegrid')
plt.rcParams['figure.figsize'] = (15, 8)
# Count of the pickups based on the month
dfAggValues.plot.bar(x='Date', y='Count')
